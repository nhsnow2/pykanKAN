# %% [markdown]
# We desire to demonstrate a KAN on the following division:
# $$ f(x_1.x_2,x_3, x_4) = \sqrt{(x_1-x_2)^2+(x_3-x_4)^2} $$

# %%
# Imports
import torch
torch.set_default_dtype(torch.float64)
for i in range(torch.cuda.device_count()):
    print(f'Device: {torch.cuda.get_device_properties(i).name}')
if torch.cuda.is_available():
    i = 0
    torch.cuda.set_device(i)
    torch.set_default_device(f'cuda:{i}')
    print(f"Cuda is available. Setting default device to: {torch.cuda.get_device_properties(i).name}")
else:
    print('Cuda is not available. Setting default device to: CPU')
import kan
import numpy as np
import matplotlib.pyplot as plt
import scipy
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score as R2
from sklearn.metrics import mean_squared_error as MSE
from sklearn.metrics import mean_absolute_error as MAE
# Out:
# Device: NVIDIA T400 4GB
# Cuda is available. Setting default device to: NVIDIA T400 4GB

# %% [markdown]
# #### 1. Data Generation

# %%
# Generate Toy Data
generator = np.random.default_rng(seed=43)
x_1 = (generator.random(10000, dtype=float)*1)
x_2 = (generator.random(10000, dtype=float)*1)
x_3 = (generator.random(10000, dtype=float)*1)
x_4 = (generator.random(10000, dtype=float)*1)
X = np.asarray([x_1, x_2, x_3, x_4]).transpose()
Y = np.sqrt((x_1-x_2)**2+(x_3-x_4)**2)

# %%
# Test-train split
X_TRAIN, X_TESTS, Y_TRAIN, Y_TESTS = train_test_split(X,Y, test_size=0.25, random_state=43, shuffle=True)

# %%
# SCALE DATA
scale = True
if scale:
    X_Scaler = StandardScaler()
    Y_Scaler = StandardScaler()
    X_TRAIN_S = X_Scaler.fit_transform(X_TRAIN) #
    X_TESTS_S = X_Scaler.transform(X_TESTS) #

    Y_TRAIN_S = Y_Scaler.fit_transform(Y_TRAIN.reshape(-1,1)) #
    Y_TESTS_S = Y_Scaler.transform(Y_TESTS.reshape(-1,1)) #
else:
    X_Scaler = StandardScaler(with_mean=False, with_std=False)
    Y_Scaler = StandardScaler(with_mean=False, with_std=False)
    X_TRAIN_S = X_Scaler.fit_transform(X_TRAIN) #
    X_TESTS_S = X_Scaler.transform(X_TESTS) #

    Y_TRAIN_S = Y_Scaler.fit_transform(Y_TRAIN.reshape(-1,1)) #
    Y_TESTS_S = Y_Scaler.transform(Y_TESTS.reshape(-1,1)) #

# %%
# Convert to Tensors
#X_TRAIN_T, X_TESTS_T = torch.from_numpy(X_TRAIN_S).float(), torch.from_numpy(X_TESTS_S).float()
#Y_TRAIN_T, Y_TESTS_T = torch.from_numpy(Y_TRAIN_S).float(), torch.from_numpy(Y_TESTS_S).float()
X_TRAIN_T, X_TESTS_T = torch.tensor(X_TRAIN_S, device='cuda:0'), torch.tensor(X_TESTS_S, device='cuda:0')
Y_TRAIN_T, Y_TESTS_T = torch.tensor(Y_TRAIN_S, device='cuda:0'), torch.tensor(Y_TESTS_S, device='cuda:0')

# %%
# Format as DATASET
DATASET = {'train_input':X_TRAIN_T, 'test_input':X_TESTS_T, 'train_label':Y_TRAIN_T, 'test_label':Y_TESTS_T}
print(f"X Features Shape:\t({X.shape[0]} Samples) x ({X.shape[1]} Features)\t\tSplit Into: ({X_TRAIN.shape[0]}/{X_TESTS.shape[0]}) Train/Test Samples")
print(f"Y Features Shape:\t({Y.shape[0]} Samples) x ({1} Features)\t\tSplit Into: ({Y_TRAIN.shape[0]}/{Y_TESTS.shape[0]}) Train/Test Samples")
# Out:
# X Features Shape:	(10000 Samples) x (4 Features)		Split Into: (7500/2500) Train/Test Samples
# Y Features Shape:	(10000 Samples) x (1 Features)		Split Into: (7500/2500) Train/Test Samples

# %%
f = lambda x: torch.sqrt(torch.square(x[:,[0]]-x[:,[1]])-torch.square(x[:,[2]]-x[:,[3]]))
alternative_dataset = kan.create_dataset(f, n_var=4, ranges=[-1,1],train_num=10000, test_num=1000, normalize_input=True, normalize_label=True, device='cuda:0', seed=43)

# %% [markdown]
# #### 2. KAN Construction and Training

# %%
def training_plot(history):
    fig, axs = plt.subplots(1,1)
    axs.plot([i for i in range(len(history["train"]))], history["train"])
    axs.plot([i for i in range(len(history["tests"]))], history["tests"])
    axs.set_yscale('log'); axs.set_ylabel('Loss');axs.set_xlabel("Steps"); axs.grid(visible=True, which='both')
    return axs

def Initialize(
               training_dataset,
               network_width = [4,3,3,1],
               spline_grid = 8,
               rng_seed = 43,
               spline_order = 3,
               device = 'cuda:0',
               plot = True,
               **kwargs
               ):
    
    model = kan.KAN(width=network_width, grid=spline_grid, seed=rng_seed, k=spline_order, device=device, **kwargs)
    model(training_dataset)
    if plot: model.plot()
    history = {"train":[],"tests":[]}

    return model, history

def Train(
          model,
          dataset,
          history,
          epochs = 400,
          reg_rate = 0.01,
          learning_rate = 0.05,
          optimizer='Adam',
          plot = True,
          **kwargs
          ):
    result = model.fit(dataset, opt=optimizer, steps=epochs, lamb=reg_rate, lr=learning_rate, **kwargs)
    history["train"] += result["train_loss"]
    history["tests"] += result["test_loss"]
    if plot:
        model.plot()
        training_plot(history)
        
    return history

def Prune(
          model,
          node_threshold = None,
          edge_threshold = None,
          plot = True
         ):
    if node_threshold is not None and edge_threshold is not None:
        model = model.prune(node_threshold, edge_threshold)
    else:
        model = model.prune()
    
    if plot: model.plot()
    return model

def Refine(
           model,
           factor,
           plot = True
          ):
    model.refine(factor)
    print(f"New grid: {model.grid}")
    if plot:
        model.plot()
    return model

# %%
def Symbolize(
              model,
              function_library = ['x^3','x^4','x^2','sqrt'],
              round_off = 4,
             ):
    from kan.utils import ex_round
    model.auto_symbolic(lib=function_library)
    
    return ex_round(model.symbolic_formula()[0][0], 4)

def PlotInput(
              Y,
              x_1,
              x_2 = None,
             ):
    i = 3 if x_2 else 1
    fig, axs = plt.subplots(1,i, figsize=(12,4))

    if i != 1: ax=axs[0]
    else: axs
    ax.scatter(x_1, Y, s=3, alpha=0.25)
    if i != 1:
        ax=axs[1]
        ax.scatter(x_2, Y, s=3, alpha=0.25)

        fig.delaxes(axs[2])
        ax=fig.add_subplot(1,3,3,projection='3d')
        ax.scatter(x_1, x_2, Y, s=3, alpha=0.15)
    return

def PlotPerformance(
                    model,
                    dataset,
                    scale = True,
                   ):
    # --- Results - Performance
    X_TESTS_T = dataset['train_input']
    if scale:
        Y_PREDICTED = Y_Scaler.inverse_transform(model(X_TESTS_T).detach().reshape(-1,1).cpu()) # model(X_TESTS_T).detach() #
    else:
        Y_PREDICTED = model(X_TESTS_T).detach().cpu()

    if scale:
        Y_TRUE = Y_Scaler.inverse_transform(dataset['train_label'].detach().reshape(-1,1).cpu())
    else:
        Y_TRUE = dataset['train_label'].detach().cpu().numpy()

    print(Y_TRUE.shape); print(Y_PREDICTED.shape)
    myR2 = R2(Y_TRUE, Y_PREDICTED); myMSE = MSE(Y_TRUE, Y_PREDICTED); myMAE = MAE(Y_TRUE, Y_PREDICTED)

    fig, axs = plt.subplots(1,2, figsize=(12,4))

    ax=axs[0]
    ax.scatter(Y_TRUE, Y_PREDICTED, alpha=0.25, label=f"R2: {round(myR2,3)}\nMAE: {round(myMAE,3)}\nRMSE: {round(myMSE**0.5,3)}")
    ax.plot(np.linspace(np.min(Y_TRUE), np.max(Y_TRUE),100),np.linspace(np.min(Y_TRUE), np.max(Y_TRUE),100), color='black',ls='--', label="f(x1,x2,x3,x4)")
    ax.set_xlabel("f(x1,x2,x3,x4)"); ax.set_ylabel("KAN(x1,x2,x3,x4)"); ax.legend(); ax.grid(visible=True, color='gainsboro')

    ax=axs[1]
    residuals = Y_PREDICTED - Y_TRUE
    pdf_fit = scipy.stats.norm.fit(residuals)
    pdf_pdf = scipy.stats.norm.pdf(np.linspace(-0.3,0.3,100), *pdf_fit)
    ax.hist(residuals, bins=100, color='cornflowerblue', density=True)
    ax.plot(np.linspace(-0.3,0.3,100), pdf_pdf, label=f'Gaussian Fit: {[round(i,3) for i in pdf_fit]}')
    ax.set_xlabel("Residual"); ax.set_ylabel("Relative Frequency"); ax.grid(visible=True, color='gainsboro', label='Raw Data'); ax.legend()

    fig.tight_layout()

    return

# %%
model, history = Initialize(DATASET['train_input'], network_width=[4,3,3,1], plot=False, spline_order=3, spline_grid=8)
# Out:
# checkpoint directory created: ./model
# saving model version 0.0

# %%
history = Train(model, DATASET, history, plot=True, epochs=100, learning_rate=0.01, reg_rate=0.01, optimizer='Adam')
# Out:
# | train_loss: nan | test_loss: nan | reg: nan | : 100%|███████████| 100/100 [00:06<00:00, 16.59it/s]
# saving model version 0.8
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[132], line 1
# ----> 1 history = Train(model, DATASET, history, plot=True, epochs=100, learning_rate=0.01, reg_rate=0.01, optimizer='Adam')
#
# Cell In[56], line 41, in Train(model, dataset, history, epochs, reg_rate, learning_rate, optimizer, plot, **kwargs)
#      39 history["tests"] += result["test_loss"]
#      40 if plot:
# ---> 41     model.plot()
#      42     training_plot(history)
#      44 return history
#
# File c:\Users\nhsnow2\AppData\Local\anaconda3\envs\KAN\lib\site-packages\kan\MultKAN.py:1199, in MultKAN.plot(self, folder, beta, metric, scale, tick, sample, in_vars, out_vars, title, varscale)
#    1196                 color = "white"
#    1197                 alpha_mask = 0.
# ...

# %%
model = Prune(model, node_threshold=None, edge_threshold=None)
# Out:
# saving model version 0.5

# %%
PlotPerformance(model, DATASET, scale=True)
# Out:
# (7500, 1)
# (7500, 1)

# %%
Symbolize(model, function_library=['x','x^2','x^3','x^4','sqrt'])
# Out:
# fixing (0,0,0) with 0
# fixing (0,0,1) with x, r2=0.9999825697447966, c=1
# fixing (0,1,0) with 0
# fixing (0,1,1) with x, r2=0.9999747405752645, c=1
# fixing (0,2,0) with x, r2=0.9999812763066078, c=1
# fixing (0,2,1) with 0
# fixing (0,3,0) with x, r2=0.9999911498712232, c=1
# fixing (0,3,1) with 0
# fixing (1,0,0) with x^2, r2=0.9964560245123298, c=2
# fixing (1,1,0) with x^2, r2=0.9983702665060259, c=2
# fixing (2,0,0) with sqrt, r2=0.9982100527187077, c=2
# saving model version 0.7
# 2.8259*sqrt(0.0857*(1.4475*x_1 - 1.4352*x_2 + 0.0155)**2 + 0.2464*(0.8507*x_3 - 0.8554*x_4 + 0.0274)**2 + 0.0649) - 2.2844
