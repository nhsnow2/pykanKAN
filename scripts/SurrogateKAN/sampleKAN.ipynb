# %% [markdown]
# ### [1] Prep

# %%
# --- imports
# Models
import torch
import kan
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.gaussian_process.kernels import RBF, RationalQuadratic, ConstantKernel, CompoundKernel, WhiteKernel
# Data handling
import numpy as np
import pandas as pd
# plotting
import matplotlib
matplotlib.rc('font', family='Palatino Linotype')
from matplotlib import pyplot as plt

# %% [markdown]
# ### [2] Data

# %%
# --- Load Data
input_data = []
for i in range(1,8):
    input_data.append(np.load(f"../samples/SampleXS_{i}.npy"))
input_data = np.array(input_data)
output_data = np.load(f"../samples/SampleOutput.npy")

# %%
# --- Flatten Data
#print(f"Pre-Inputs Shape:\t{[i.shape for i in input_data]}")
print("Inputs")
print("_____________________________")
print(f"Pre:\t{input_data.shape}") #type:ignore
flattened_inputs = input_data.reshape(500, 81*16*7) #type:ignore
print(f"Post:\t{flattened_inputs.shape}") #type:ignore

print("_____________________________")
print("Outputs")
print("_____________________________")
print(f"Pre:\t{[output_data.shape]}")
flattened_outputs = output_data.reshape((500,81*16))
print(f"Post:\t{flattened_outputs.shape}")
# Out:
# Inputs
# _____________________________
# Pre:	(7, 500, 81, 16)
# Post:	(500, 9072)
# _____________________________
# Outputs
# _____________________________
# Pre:	[(500, 81, 16)]
# Post:	(500, 1296)

# %%
# --- Sample Splitting
train_X, test_X = train_test_split(flattened_inputs, test_size=0.2)
train_Y, test_Y = train_test_split(flattened_outputs, test_size=0.2)

print(f"Train X:\t{train_X.shape}\tTest X:\t{test_X.shape}")
print(f"Train Y:\t{train_Y.shape}\tTest Y:\t{test_Y.shape}")
# Out:
# Train X:	(400, 9072)	Test X:	(100, 9072)
# Train Y:	(400, 1296)	Test Y:	(100, 1296)

# %%
# --- Data Scaling
X_scaler = StandardScaler()
Y_scaler = StandardScaler()
#
train_XS = X_scaler.fit_transform(train_X)
train_YS = Y_scaler.fit_transform(train_Y)

test_XS = X_scaler.transform(test_X)
test_YS = Y_scaler.transform(test_Y)

# %%
# --- Conversion to Torch tensors
train_XST = torch.tensor(train_XS)
train_YST = torch.tensor(train_YS)
test_XST = torch.tensor(test_XS)
test_YST = torch.tensor(test_YS)

# %%
DATASET = {'train_input':train_XST, 'test_input':train_YST, 'train_label':test_XST, 'test_label':test_YST}

# %% [markdown]
# ### [3] KAN

# %%
# --- KAN Training
model = kan.KAN([train_XST.shape[1], train_XST.shape[1], train_YST.shape[1]], grid=2, k=3)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 2
#       1 # --- KAN Training
# ----> 2 model = kan.KAN([train_XST.shape[1], train_XST.shape[1], train_YST.shape[1]], grid=2, k=3)
#
# File c:\Users\nhsnow2\AppData\Local\anaconda3\envs\KAN\lib\site-packages\kan\MultKAN.py:245, in MultKAN.__init__(self, width, grid, k, mult_arity, noise_scale, scale_base_mu, scale_base_sigma, base_fun, symbolic_enabled, affine_trainable, grid_eps, grid_range, sp_trainable, sb_trainable, seed, save_act, sparse_init, auto_save, first_init, ckpt_path, state_id, round, device)
#     243 self.symbolic_fun = []
#     244 for l in range(self.depth):
# --> 245     sb_batch = Symbolic_KANLayer(in_dim=width_in[l], out_dim=width_out[l+1])
#     246     self.symbolic_fun.append(sb_batch)
#     248 self.symbolic_fun = nn.ModuleList(self.symbolic_fun)
#
# File c:\Users\nhsnow2\AppData\Local\anaconda3\envs\KAN\lib\site-packages\kan\Symbolic_KANLayer.py:57, in Symbolic_KANLayer.__init__(self, in_dim, out_dim, device)
#      55 # torch
#      56 self.funs = [[lambda x: x*0. for i in range(self.in_dim)] for j in range(self.out_dim)]
# ---> 57 self.funs_avoid_singularity = [[lambda x, y_th: ((), x*0.) for i in range(self.in_dim)] for j in range(self.out_dim)]
#      58 # name
#      59 self.funs_name = [['0' for i in range(self.in_dim)] for j in range(self.out_dim)]
#
# File c:\Users\nhsnow2\AppData\Local\anaconda3\envs\KAN\lib\site-packages\kan\Symbolic_KANLayer.py:57, in <listcomp>(.0)
#      55 # torch
#      56 self.funs = [[lambda x: x*0. for i in range(self.in_dim)] for j in range(self.out_dim)]
# ---> 57 self.funs_avoid_singularity = [[lambda x, y_th: ((), x*0.) for i in range(self.in_dim)] for j in range(self.out_dim)]
#      58 # name
#      59 self.funs_name = [['0' for i in range(self.in_dim)] for j in range(self.out_dim)]
#
# File c:\Users\nhsnow2\AppData\Local\anaconda3\envs\KAN\lib\site-packages\kan\Symbolic_KANLayer.py:57, in <listcomp>(.0)
#      55 # torch
#      56 self.funs = [[lambda x: x*0. for i in range(self.in_dim)] for j in range(self.out_dim)]
# ---> 57 self.funs_avoid_singularity = [[lambda x, y_th: ((), x*0.) for i in range(self.in_dim)] for j in range(self.out_dim)]
#      58 # name
#      59 self.funs_name = [['0' for i in range(self.in_dim)] for j in range(self.out_dim)]
#
# KeyboardInterrupt:

# %%
model(DATASET['train_input'])

# %% [markdown]
# #### [3.1] Construction and Training

# %% [markdown]
# #### [3.2] Refinement and Pruning

# %% [markdown]
# #### [3.3] Error Analysis

# %% [markdown]
# #### [3.4] Reconstructed Error
